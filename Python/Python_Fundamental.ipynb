# %% [markdown]
# # 1. Python Output

# %%
print('Hello World')
# Out:
# Hello World

# %%
print('salmn khan')
# Out:
# salmn khan

# %%
print(7)
# Out:
# 7

# %%
print(7.7)
# Out:
# 7.7

# %%
print(True)
# Out:
# True

# %%
print('Hello',1,4.5,True)
# Out:
# Hello 1 4.5 True

# %%
print('Hello',1,4.5,True,sep='/')
# Out:
# Hello/1/4.5/True

# %%
print('Hello')
print('world')
# Out:
# Hello
# world

# %%
print('Hello',end='-')
print('world')
# Out:
# Hello-world
